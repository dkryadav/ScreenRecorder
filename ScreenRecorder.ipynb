# %%
# !pip install pyscreenshot
import numpy as np
import cv2
import pyscreenshot as pys

forcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output.avi', forcc, 8, (1920,1080))


while True:
    img= pys.grab(childprocess=False)
    img_np=np.array(img)

    # frame= cv2.cvtColor(img_np, cv2.COLOR_BGR2GRAY)

    cv2.imshow('Screen', img_np)
    out.write(img_np)


    if cv2.waitKey(20) & 0xFF==ord('q'):
        break

out.release()
cv2.destroyAllWindows()
# Out:
# Requirement already satisfied: pyscreenshot in /usr/local/lib/python3.6/dist-packages (0.5.1)
# Requirement already satisfied: EasyProcess in /usr/local/lib/python3.6/dist-packages (from pyscreenshot) (0.2.7)
# ---------------------------------------------------------------------------
# FailedBackendError                        Traceback (most recent call last)
# <ipython-input-14-e0e324c12a06> in <module>()
#       9
#      10 while True:
# ---> 11     img= pys.grab(childprocess=False)
#      12     img_np=np.array(img)
#      13
#
# /usr/local/lib/python3.6/dist-packages/pyscreenshot/__init__.py in grab(bbox, childprocess, backend)
#      65         childprocess = childprocess_default_value()
#      66     return _grab(
# ---> 67         to_file=False, childprocess=childprocess, backend=backend, bbox=bbox)
#      68
#      69
#
# /usr/local/lib/python3.6/dist-packages/pyscreenshot/__init__.py in _grab(to_file, childprocess, backend, bbox, filename)
#      46             _grab_simple, imcodec.codec, to_file, backend, bbox, filename)
#      47     else:
# ---> 48         return _grab_simple(to_file, backend, bbox, filename)
#      49
#      50
#
# /usr/local/lib/python3.6/dist-packages/pyscreenshot/__init__.py in _grab_simple(to_file, backend, bbox, filename)
#      26     loader = Loader()
#      27     loader.force(backend)
# ---> 28     backend_obj = loader.selected()
#      29
#      30     if to_file:
#
# /usr/local/lib/python3.6/dist-packages/pyscreenshot/loader.py in selected(self)
#      80                 b = self.get_valid_plugin_by_list(biglist)
#      81                 if not b:
# ---> 82                     self.raise_exc()
#      83             self.changed = False
#      84             self._backend = b
#
# /usr/local/lib/python3.6/dist-packages/pyscreenshot/loader.py in raise_exc(self)
#      88     def raise_exc(self):
#      89         message = 'Install at least one backend!'
# ---> 90         raise FailedBackendError(message)
#
# FailedBackendError: Install at least one backend!

# %%
import pyscreenshot as pys
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-260a57a204c8> in <module>()
# ----> 1 import pyscreenshot as pys
#
# ModuleNotFoundError: No module named 'pyscreenshot'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !apt-get -qq install python-cartopy python3-cartopy
import cartopy
